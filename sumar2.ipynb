# %% [markdown]
# <a href="https://colab.research.google.com/github/josueoteiza/FPY1101-006V/blob/main/sumar2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("Ingrese primer numero: "))
num2=int(input("Ingrese segundo numero: "))

sumar=num1 + num2

print("El resultado es: ", sumar)
# Out:
# Ingrese primer numero: 5
# Ingrese segundo numero: 2
# El resultado es:  7
